# %% [markdown]
# <a href="https://colab.research.google.com/github/ashajyothi-2005/HTML/blob/main/python_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Add Two Numbers")
a = 5
b = 3
print(a + b)
# Out:
# Add Two Numbers
# 8

# %%
print("Input From User")
name = input("Enter your name: ")
print("Hello,", name)
# Out:
# Input From User
# Enter your name: and
# Hello, and

# %%
print("Check Even or Odd")
n = int(input("Enter a number: "))
print("Even" if n % 2 == 0 else "Odd")
# Out:
# Check Even or Odd
# Enter a number: 23
# Odd

# %%
print("Find Largest of Three Numbers")
a, b, c = 10, 20, 5
print(max(a, b, c))
# Out:
# Find Largest of Three Numbers
# 20

# %%
print("Simple If-Else")
x = 10
if x > 5:
    print("Greater than 5")
else:
    print("Not greater than 5")
# Out:
# Simple If-Else
# Greater than 5

# %%
print("For Loop (1–5)")
for i in range(1, 6):
    print(i)
# Out:
# For Loop (1–5)
# 1
# 2
# 3
# 4
# 5

# %%
print("While Loop")
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# While Loop
# 1
# 2
# 3
# 4
# 5

# %%
nums = [1, 2, 3, 4]
print(sum(nums))
# Out:
# 10

# %%
def longest_substring(s):
    char_set = set()
    left = result = 0

    for right in range(len(s)):
        while s[right] in char_set:
            char_set.remove(s[left])
            left += 1
        char_set.add(s[right])
        result = max(result, right - left + 1)

    return result

# %%
def product_except_self(nums):
    n = len(nums)
    output = [1] * n

    prefix = 1
    for i in range(n):
        output[i] = prefix
        prefix *= nums[i]

    postfix = 1
    for i in range(n - 1, -1, -1):
        output[i] *= postfix
        postfix *= nums[i]

    return output

# %%
def rotate_matrix(matrix):
    n = len(matrix)

    # transpose
    for i in range(n):
        for j in range(i + 1, n):
            matrix[i][j], matrix[j][i] = matrix[j][i], matrix[i][j]

    # reverse rows
    for row in matrix:
        row.reverse()

    return matrix

# %%
from collections import defaultdict

def group_anagrams(strs):
    groups = defaultdict(list)

    for s in strs:
        key = tuple(sorted(s))
        groups[key].append(s)

    return list(groups.values())

# %%
from collections import deque

def level_order(root):
    if not root:
        return []

    queue = deque([root])
    result = []

    while queue:
        size = len(queue)
        level = []
        for _ in range(size):
            node = queue.popleft()
            level.append(node.val)
            if node.left: queue.append(node.left)
            if node.right: queue.append(node.right)
        result.append(level)

    return result

# %%
def find_peak(nums):
    left, right = 0, len(nums) - 1

    while left < right:
        mid = (left + right) // 2
        if nums[mid] < nums[mid + 1]:
            left = mid + 1
        else:
            right = mid

    return left  # index of peak

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def add_two_numbers(l1, l2):
    dummy = ListNode()
    cur = dummy
    carry = 0

    while l1 or l2 or carry:
        v1 = l1.val if l1 else 0
        v2 = l2.val if l2 else 0

        total = v1 + v2 + carry
        carry = total // 10

        cur.next = ListNode(total % 10)
        cur = cur.next

        l1 = l1.next if l1 else None
        l2 = l2.next if l2 else None

    return dummy.next

# %%
def merge_intervals(intervals):
    intervals.sort()
    merged = [intervals[0]]

    for start, end in intervals[1:]:
        last_end = merged[-1][1]
        if start <= last_end:
            merged[-1][1] = max(last_end, end)
        else:
            merged.append([start, end])

    return merged

# %%
import heapq

def kth_largest(nums, k):
    heap = []

    for n in nums:
        heapq.heappush(heap, n)
        if len(heap) > k:
            heapq.heappop(heap)

    return heap[0]

# %%
from collections import deque

def word_ladder(begin, end, word_list):
    word_set = set(word_list)
    queue = deque([(begin, 1)])

    while queue:
        word, steps = queue.popleft()
        if word == end:
            return steps

        for i in range(len(word)):
            for c in "abcdefghijklmnopqrstuvwxyz":
                new_word = word[:i] + c + word[i+1:]
                if new_word in word_set:
                    word_set.remove(new_word)
                    queue.append((new_word, steps + 1))

    return 0
